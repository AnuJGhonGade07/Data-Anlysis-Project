# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
color=['violet','golden','pink','brown']

# %%
df1=pd.read_csv('C:\\Users\\anujg\\PROJECT\\1. Student_Performance_Factors\\SPF.csv')
df1
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
df=df1.head(500)

# %%
df=df.drop(columns=['Teacher_Quality','Peer_Influence','Distance_from_Home'])	
df
# Out:
#      Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0               23          84                  Low                High
# 1               19          64                  Low              Medium
# 2               24          98               Medium              Medium
# 3               29          89                  Low              Medium
# 4               19          92               Medium              Medium
# ..             ...         ...                  ...                 ...
# 495             23          88                  Low              Medium
# 496             14          89                 High                High
# 497             19          88                 High              Medium
# 498             15          72                 High                High
# 499             12          64                 High                 Low
#
#     Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# ...

# %%
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income School_Type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               500 non-null    int64
#  1   Attendance                  500 non-null    int64
#  2   Parental_Involvement        500 non-null    object
#  3   Access_to_Resources         500 non-null    object
#  4   Extracurricular_Activities  500 non-null    object
#  5   Sleep_Hours                 500 non-null    int64
#  6   Previous_Scores             500 non-null    int64
#  7   Motivation_Level            500 non-null    object
#  8   Internet_Access             500 non-null    object
#  9   Tutoring_Sessions           500 non-null    int64
#  10  Family_Income               500 non-null    object
#  11  School_Type                 500 non-null    object
#  12  Physical_Activity           500 non-null    int64
# ...

# %%
df['Hours_Studied']
# Out:
# 0      23
# 1      19
# 2      24
# 3      29
# 4      19
#        ..
# 495    23
# 496    14
# 497    19
# 498    15
# 499    12
# Name: Hours_Studied, Length: 500, dtype: int64

# %%
df['Attendance']
# Out:
# 0      84
# 1      64
# 2      98
# 3      89
# 4      92
#        ..
# 495    88
# 496    89
# 497    88
# 498    72
# 499    64
# Name: Attendance, Length: 500, dtype: int64

# %%
df['Parental_Involvement'].unique()
# Out:
# array(['Low', 'Medium', 'High'], dtype=object)

# %%
df['Parental_Involvement'].value_counts()
# Out:
# Parental_Involvement
# Medium    270
# High      127
# Low       103
# Name: count, dtype: int64

# %%
df['Access_to_Resources'].unique()
# Out:
# array(['High', 'Medium', 'Low'], dtype=object)

# %%
df['Access_to_Resources'].unique()
# Out:
# array(['High', 'Medium', 'Low'], dtype=object)

# %%
df['Access_to_Resources'].value_counts()
# Out:
# Access_to_Resources
# Medium    254
# High      152
# Low        94
# Name: count, dtype: int64

# %%
df['Extracurricular_Activities'].value_counts()
# Out:
# Extracurricular_Activities
# Yes    301
# No     199
# Name: count, dtype: int64

# %%
df['Sleep_Hours']
# Out:
# 0      7
# 1      8
# 2      7
# 3      8
# 4      6
#       ..
# 495    7
# 496    4
# 497    5
# 498    8
# 499    6
# Name: Sleep_Hours, Length: 500, dtype: int64

# %%
df['Motivation_Level'].value_counts()
# Out:
# Motivation_Level
# Medium    268
# Low       140
# High       92
# Name: count, dtype: int64

# %%
df['Internet_Access'].value_counts()
# Out:
# Internet_Access
# Yes    457
# No      43
# Name: count, dtype: int64

# %%
df['Tutoring_Sessions']
# Out:
# 0      0
# 1      2
# 2      2
# 3      1
# 4      3
#       ..
# 495    1
# 496    2
# 497    2
# 498    2
# 499    0
# Name: Tutoring_Sessions, Length: 500, dtype: int64

# %%
df['Tutoring_Sessions'].unique()
# Out:
# array([0, 2, 1, 3, 4, 5], dtype=int64)

# %%
df['Family_Income'].value_counts()
# Out:
# Family_Income
# Medium    225
# Low       191
# High       84
# Name: count, dtype: int64

# %%
df['School_Type'].value_counts()
# Out:
# School_Type
# Public     359
# Private    141
# Name: count, dtype: int64

# %%
df['Physical_Activity']
# Out:
# 0      3
# 1      4
# 2      4
# 3      4
# 4      4
#       ..
# 495    2
# 496    3
# 497    4
# 498    4
# 499    2
# Name: Physical_Activity, Length: 500, dtype: int64

# %%
df['Physical_Activity'].unique()
# Out:
# array([3, 4, 2, 1, 5, 0, 6], dtype=int64)

# %%
df['Learning_Disabilities'].value_counts()
# Out:
# Learning_Disabilities
# No     438
# Yes     62
# Name: count, dtype: int64

# %%
df['Parental_Education_Level'].value_counts()
# Out:
# Parental_Education_Level
# High School     244
# College         158
# Postgraduate     94
# Name: count, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      292
# Female    208
# Name: count, dtype: int64

# %%
df['Exam_Score']
# Out:
# 0      67
# 1      61
# 2      74
# 3      71
# 4      70
#        ..
# 495    67
# 496    70
# 497    69
# 498    65
# 499    61
# Name: Exam_Score, Length: 500, dtype: int64

# %%
df.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'School_Type',
#        'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Gender', 'Exam_Score'],
#       dtype='object')

# %%
continous=['Hours_Studied', 'Attendance','Previous_Scores','Exam_Score']
discreate_categorical=['Parental_Involvement','Access_to_Resources', 'Extracurricular_Activities', 'Motivation_Level', 'Internet_Access',
                       'Family_Income', 'School_Type','Learning_Disabilities',
                       'Parental_Education_Level','Gender']
discreate_count=['Sleep_Hours','Tutoring_Sessions','Physical_Activity']

# %%
df[continous].describe()
# Out:
#        Hours_Studied  Attendance  Previous_Scores  Exam_Score
# count     500.000000  500.000000       500.000000  500.000000
# mean       20.050000   79.262000        75.968000   67.084000
# std         5.886663   11.331114        14.378333    3.762081
# min         1.000000   60.000000        50.000000   59.000000
# 25%        16.000000   69.750000        64.750000   65.000000
# 50%        20.000000   78.500000        77.000000   67.000000
# 75%        24.000000   88.000000        88.000000   69.000000
# max        43.000000  100.000000       100.000000  100.000000

# %%
df[continous].skew()
# Out:
# Hours_Studied      0.178246
# Attendance         0.100251
# Previous_Scores   -0.164751
# Exam_Score         2.097317
# dtype: float64

# %%
df[discreate_categorical].describe()
# Out:
#        Parental_Involvement Access_to_Resources Extracurricular_Activities  \
# count                   500                 500                        500
# unique                    3                   3                          2
# top                  Medium              Medium                        Yes
# freq                    270                 254                        301
#
#        Motivation_Level Internet_Access Family_Income School_Type  \
# count               500             500           500         500
# unique                3               2             3           2
# top              Medium             Yes        Medium      Public
# freq                268             457           225         359
#
#        Learning_Disabilities Parental_Education_Level Gender
# count                    500                      496    500
# unique                     2                        3      2
# top                       No              High School   Male
# ...

# %%
df.isnull().sum()
# Out:
# Hours_Studied                 0
# Attendance                    0
# Parental_Involvement          0
# Access_to_Resources           0
# Extracurricular_Activities    0
# Sleep_Hours                   0
# Previous_Scores               0
# Motivation_Level              0
# Internet_Access               0
# Tutoring_Sessions             0
# Family_Income                 0
# School_Type                   0
# Physical_Activity             0
# Learning_Disabilities         0
# Parental_Education_Level      4
# Gender                        0
# Exam_Score                    0
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# Hours_Studied                 0
# Attendance                    0
# Parental_Involvement          0
# Access_to_Resources           0
# Extracurricular_Activities    0
# Sleep_Hours                   0
# Previous_Scores               0
# Motivation_Level              0
# Internet_Access               0
# Tutoring_Sessions             0
# Family_Income                 0
# School_Type                   0
# Physical_Activity             0
# Learning_Disabilities         0
# Parental_Education_Level      0
# Gender                        0
# Exam_Score                    0
# dtype: int64

# %%
df.to_excel('cleaned_data.xlsx', index=False)

# %%
sns.relplot(x='Sleep_Hours',y='Physical_Activity',hue='Gender',data=df,kind='line')

# %% [markdown]
# Student who done more physical activity can sleep More.

# %%
plt.scatter(df['Hours_Studied'],df['Attendance'])
plt.title("Attendence and Hours of study Analysis")
plt.xlabel("Hours_study")
plt.ylabel("Attendence")
# Out:
# Text(0, 0.5, 'Attendence')

# %% [markdown]
# From the Above Scatter plot we observe that students having above 80% Attendence can Study more than 30 Hours in week

# %%
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income School_Type  \
# ...

# %%
sns.scatterplot(x=df['Hours_Studied'],y=df['Exam_Score'],hue=df['Gender'])
plt.title('Hours of study vs Exam Score')
# Out:
# Text(0.5, 1.0, 'Hours of study vs Exam Score')

# %% [markdown]
# From the above plot we can see the female students get more marks than male with just doing study in less time

# %%
x=df['Access_to_Resources']
y=df['Exam_Score']
plt.bar(x,y)
plt.title("Marks vs Availability of Resources")
plt.xlabel("Resources Availability")
plt.ylabel("Marks")
# Out:
# Text(0, 0.5, 'Marks')

# %% [markdown]
# Students from medium access of resources can score more marks

# %%
sns.histplot(df['Sleep_Hours'],bins=7)
# Out:
# <Axes: xlabel='Sleep_Hours', ylabel='Count'>

# %% [markdown]
# More Number of students sleep 7 hours in a day

# %%
sns.kdeplot(df['Previous_Scores'])
# Out:
# <Axes: xlabel='Previous_Scores', ylabel='Density'>

# %%
df.groupby("Gender")["Attendance"].mean()
# Out:
# Gender
# Female    78.478261
# Male      79.754325
# Name: Attendance, dtype: float64

# %%
sns.catplot(x='Gender',y='Attendance',data=df,kind='bar')

# %% [markdown]
# Males Have more attend the school than female

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x='Sleep_Hours',y='Exam_Score',hue='Motivation_Level',data=df)
plt.legend(title='Motivation_Level', bbox_to_anchor=(1.28,1), loc='upper right')

# %%
sns.relplot(x='Previous_Scores',y='Exam_Score',hue='Gender',data=df,kind='line')

# %%
fig, ax = plt.subplots(nrows=2,ncols=2,figsize=(10,10))

ax[0,0].scatter(df['Hours_Studied'],df['Sleep_Hours'],color='brown')
ax[0,1].scatter(df['Previous_Scores'],df['Exam_Score'],color='blue')
ax[1,0].hist(df['Previous_Scores'])
ax[1,1].hist(df['Exam_Score'])
# Out:
# (array([ 70., 220., 161.,  39.,   3.,   0.,   1.,   1.,   0.,   1.]),
#  array([ 59. ,  63.1,  67.2,  71.3,  75.4,  79.5,  83.6,  87.7,  91.8,
#          95.9, 100. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x='Tutoring_Sessions',y='Exam_Score',hue='School_Type',data=df)
plt.legend(title='Motivation_Level', bbox_to_anchor=(1.28,1), loc='upper right')

# %% [markdown]
# From the Above plot we can observe that the students attending only 3 sessions in a private school can score more marks in exam

# %%
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income School_Type  \
# ...

# %%
sns.violinplot(x='Exam_Score',y='Parental_Involvement',data=df)
plt.show()

# %% [markdown]
# Students whose parents involved in their studies get more as compared to other students

# %%
sns.displot(x='Exam_Score',kind='hist',data=df,hue='Family_Income')
plt.title("Exam_Score vs Family Income")
# Out:
# Text(0.5, 1.0, 'Exam_Score vs Family Income')

# %%
sns.kdeplot(x='Attendance',y='Exam_Score',data=df)
# Out:
# <Axes: xlabel='Attendance', ylabel='Exam_Score'>

# %% [markdown]
# From the above plot we can observe that as the attendence increases the Exam Score also Increases.

# %%
sns.stripplot(x='Motivation_Level',y='Hours_Studied',data=df)
# Out:
# <Axes: xlabel='Motivation_Level', ylabel='Hours_Studied'>

# %%
sns.swarmplot(x='School_Type',y='Exam_Score',hue='Gender',data=df)
# Out:
# <Axes: xlabel='School_Type', ylabel='Exam_Score'>
# C:\Users\anujg\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 13.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.stripplot(x='Internet_Access',y='Exam_Score',data=df)
# Out:
# <Axes: xlabel='Internet_Access', ylabel='Exam_Score'>

# %% [markdown]
# The students having internet access can score more marks in exam
